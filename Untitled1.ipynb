# %%
import time, random, os, csv, platform
import logging
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.common.exceptions import TimeoutException
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from bs4 import BeautifulSoup
import pandas as pd
import pyautogui

from urllib.request import urlopen
from webdriver_manager.chrome import ChromeDriverManager
import re
import yaml
from datetime import datetime, timedelta

log = logging.getLogger(__name__)
driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Trying to download new driver from https://chromedriver.storage.googleapis.com/101.0.4951.41/chromedriver_win32.zip
# Driver has been saved in cache [C:\Users\trand\.wdm\drivers\chromedriver\win32\101.0.4951.41]
# C:\Users\trand\AppData\Local\Temp\ipykernel_26392\4044833363.py:22: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())

# %%
def setupLogger():
    dt = datetime.strftime(datetime.now(), "%m_%d_%y %H_%M_%S ")

    if not os.path.isdir('./logs'):
        os.mkdir('./logs')

    # TODO need to check if there is a log dir available or not
    logging.basicConfig(filename=('./logs/' + str(dt) + 'applyJobs.log'), filemode='w',
                        format='%(asctime)s::%(name)s::%(levelname)s::%(message)s', datefmt='./logs/%d-%b-%y %H:%M:%S')
    log.setLevel(logging.DEBUG)
    c_handler = logging.StreamHandler()
    c_handler.setLevel(logging.DEBUG)
    c_format = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s', '%H:%M:%S')
    c_handler.setFormatter(c_format)
    log.addHandler(c_handler)


class EasyApplyBot:
    setupLogger()
    # MAX_SEARCH_TIME is 10 hours by default, feel free to modify it
    MAX_SEARCH_TIME = 12 * 60 * 60

    def __init__(self,
                 username,
                 password,
                 uploads={},
                 filename='output.csv',
                 blacklist=[],
                 blackListTitles=[],
                 keyword_list=[]):

        log.info("Welcome to Easy Apply Bot")
        dirpath = os.getcwd()
        log.info("current directory is : " + dirpath)

        self.uploads = uploads
        past_ids = self.get_appliedIDs(filename)
        self.appliedJobIDs = past_ids if past_ids != None else []
        self.filename = filename
        self.options = self.browser_options()
        self.browser = driver
        self.wait = WebDriverWait(self.browser, 30)
        self.blacklist = blacklist
        self.blackListTitles = blackListTitles
        self.keyword_list = keyword_list
        self.start_linkedin(username, password)

    def get_appliedIDs(self, filename):
        try:
            df = pd.read_csv(filename,
                             header=None,
                             names=['timestamp', 'jobID', 'job', 'company', 'attempted', 'result'],
                             lineterminator='\n',
                             encoding='utf-8')

            df['timestamp'] = pd.to_datetime(df['timestamp'], format="%Y-%m-%d %H:%M:%S")
            df = df[df['timestamp'] > (datetime.now() - timedelta(days=2))]
            jobIDs = list(df.jobID)
            log.info(f"{len(jobIDs)} jobIDs found")
            return jobIDs
        except Exception as e:
            log.info(str(e) + "   jobIDs could not be loaded from CSV {}".format(filename))
            return None

    def browser_options(self):
        options = Options()
        options.add_argument("--start-maximized")
        options.add_argument("--ignore-certificate-errors")
        options.add_argument('--no-sandbox')
        options.add_argument("--disable-extensions")

        # Disable webdriver flags or you will be easily detectable
        options.add_argument("--disable-blink-features")
        options.add_argument("--disable-blink-features=AutomationControlled")
        return options

    def start_linkedin(self, username, password):
        log.info("Logging in.....Please wait :)  ")
        self.browser.get("https://www.linkedin.com/login?trk=guest_homepage-basic_nav-header-signin")
        try:
            user_field = self.browser.find_element_by_id("username")
            pw_field = self.browser.find_element_by_id("password")
            login_button = self.browser.find_element_by_css_selector(".btn__primary--large")
            user_field.send_keys(username)
            user_field.send_keys(Keys.TAB)
            time.sleep(2)
            pw_field.send_keys(password)
            time.sleep(2)
            login_button.click()
            time.sleep(3)
        except TimeoutException:
            log.info("TimeoutException! Username/password field or login button not found")

    def fill_data(self):
        self.browser.set_window_size(100, 100)
        self.browser.set_window_position(2000, 2000)

    def start_apply(self, positions, locations):
        start = time.time()
        self.fill_data()

        combos = []
        while len(combos) < len(positions) * len(locations):
            position = positions[random.randint(0, len(positions) - 1)]
            location = locations[random.randint(0, len(locations) - 1)]
            combo = (position, location)
            if combo not in combos:
                combos.append(combo)
                log.info(f"Applying to {position}: {location}")
                location = "&location=" + location
                self.applications_loop(position, location)
            if len(combos) > 500:
                break

    # self.finish_apply() --> this does seem to cause more harm than good, since it closes the browser which we usually don't want, other conditions will stop the loop and just break out

    def applications_loop(self, position, location):

        count_application = 0
        count_job = 0
        jobs_per_page = 0
        start_time = time.time()

        log.info("Looking for jobs.. Please wait..")

        self.browser.set_window_position(0, 0)
        self.browser.maximize_window()
        self.browser, _ = self.next_jobs_page(position, location, jobs_per_page)
        log.info("Looking for jobs.. Please wait..")

        while time.time() - start_time < self.MAX_SEARCH_TIME:
            log.info(f"{(self.MAX_SEARCH_TIME - (time.time() - start_time)) // 60} minutes left in this search")

            # sleep to make sure everything loads, add random to make us look human.
            randoTime = random.uniform(3.5, 4.9)
            log.debug(f"Sleeping for {round(randoTime, 1)}")
            time.sleep(randoTime)
            self.load_page(sleep=1)

            # LinkedIn displays the search results in a scrollable <div> on the left side, we have to scroll to its bottom

            scrollresults = self.browser.find_element_by_class_name(
                "jobs-search-results"
            )
            # Selenium only detects visible elements; if we scroll to the bottom too fast, only 8-9 results will be loaded into IDs list
            for i in range(300, 3000, 100):
                self.browser.execute_script("arguments[0].scrollTo(0, {})".format(i), scrollresults)

            time.sleep(4)

            # get job links
            links = self.browser.find_elements_by_xpath(
                '//div[@data-job-id]'
            )

            if len(links) == 0:
                break

            # get job ID of each job link
            IDs = []
            for link in links:
                children = link.find_elements_by_xpath(
                    './/a[@data-control-name]'
                )
                for child in children:
                    if child.text not in self.blacklist:
                        temp = link.get_attribute("data-job-id")
                        jobID = temp.split(":")[-1]
                        IDs.append(int(jobID))
            IDs = set(IDs)

            # remove already applied jobs
            before = len(IDs)
            jobIDs = [x for x in IDs if x not in self.appliedJobIDs]
            after = len(jobIDs)

            # it assumed that 25 jobs are listed in the results window
            if len(jobIDs) == 0 and len(IDs) > 23:
                jobs_per_page = jobs_per_page + 25
                count_job = 0
                self.avoid_lock()
                self.browser, jobs_per_page = self.next_jobs_page(position,
                                                                  location,
                                                                  jobs_per_page)
            # loop over IDs to apply
            for i, jobID in enumerate(jobIDs):
                count_job += 1
                self.get_job_page(jobID)

                # get easy apply button
                button = self.get_easy_apply_button()
                # word filter to skip positions not wanted
                
                if button is not False:
                    if any(word in self.browser.title.split(" ") for word in blackListTitles):
                        log.info('skipping this application, a blacklisted keyword was found in the job position')
                        string_easy = "* Contains blacklisted keyword"
                        result = False
                    elif any(word in self.browser.title.split(" ") for word in keyword_list):
                        string_easy = "* has Easy Apply Button"
                        log.info("Clicking the EASY apply button")
                        button.click()
                        time.sleep(3)
                        result = self.send_resume()
                        count_application += 1
                    else:
                        log.info('Job title does not contain keywords')
                        result = False
                else:
                    log.info("The button does not exist.")
                    string_easy = "* Doesn't have Easy Apply Button"
                    result = False

                position_number = str(count_job + jobs_per_page)
                log.info(f"\nPosition {position_number}:\n {self.browser.title} \n {string_easy} \n")

                self.write_to_file(button, jobID, self.browser.title, result)

                # sleep every 20 applications
                if count_application != 0 and count_application % 20 == 0:
                    sleepTime = random.randint(500, 900)
                    log.info(f"""********count_application: {count_application}************\n\n
                                Time for a nap - see you in:{int(sleepTime / 60)} min
                            ****************************************\n\n""")
                    time.sleep(sleepTime)

                # go to new page if all jobs are done
                if count_job == len(jobIDs):
                    jobs_per_page = jobs_per_page + 25
                    count_job = 0
                    log.info("""****************************************\n\n
                    Going to next jobs page, YEAAAHHH!!
                    ****************************************\n\n""")
                    self.avoid_lock()
                    self.browser, jobs_per_page = self.next_jobs_page(position,
                                                                      location,
                                                                      jobs_per_page)
        # if len(jobIDs) == 0 or i == (len(jobIDs) - 1):
        # break

    def write_to_file(self, button, jobID, browserTitle, result):
        def re_extract(text, pattern):
            target = re.search(pattern, text)
            if target:
                target = target.group(1)
            return target

        timestamp = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
        attempted = False if button == False else True
        job = re_extract(browserTitle.split(' | ')[0], r"\(?\d?\)?\s?(\w.*)")
        company = re_extract(browserTitle.split(' | ')[1], r"(\w.*)")

        toWrite = [timestamp, jobID, job, company, attempted, result]
        with open(self.filename, 'a') as f:
            writer = csv.writer(f)
            writer.writerow(toWrite)

    def get_job_page(self, jobID):

        job = 'https://www.linkedin.com/jobs/view/' + str(jobID)
        self.browser.get(job)
        self.job_page = self.load_page(sleep=0.5)
        return self.job_page

    def get_easy_apply_button(self):
        try:
            button = self.browser.find_elements_by_xpath(
                '//button[contains(@class, "jobs-apply")]/span[1]'
            )

            EasyApplyButton = button[0]
        except:
            EasyApplyButton = False

        return EasyApplyButton

    def send_resume(self):
        def is_present(button_locator):
            return len(self.browser.find_elements(button_locator[0],
                                                  button_locator[1])) > 0

        try:
            time.sleep(random.uniform(1.5, 2.5))
            next_locater = (By.CSS_SELECTOR,
                            "button[aria-label='Continue to next step']")
            review_locater = (By.CSS_SELECTOR,
                              "button[aria-label='Review your application']")
            submit_locater = (By.CSS_SELECTOR,
                              "button[aria-label='Submit application']")
            submit_application_locator = (By.CSS_SELECTOR,
                                          "button[aria-label='Submit application']")
            error_locator = (By.CSS_SELECTOR,
                             "p[data-test-form-element-error-message='true']")
            upload_locator = (By.CSS_SELECTOR, "input[name='file']")

            submitted = False
            while True:

                # Upload Cover Letter if possible
                if is_present(upload_locator):

                    input_buttons = self.browser.find_elements(upload_locator[0],
                                                               upload_locator[1])
                    for input_button in input_buttons:
                        parent = input_button.find_element(By.XPATH, "..")
                        sibling = parent.find_element(By.XPATH, "preceding-sibling::*")
                        grandparent = sibling.find_element(By.XPATH, "..")
                        for key in self.uploads.keys():
                            sibling_text = sibling.text
                            gparent_text = grandparent.text
                            if key.lower() in sibling_text.lower() or key in gparent_text.lower():
                                input_button.send_keys(self.uploads[key])

                    # input_button[0].send_keys(self.cover_letter_loctn)
                    time.sleep(random.uniform(4.5, 6.5))

                # Click Next or submitt button if possible
                button = None
                buttons = [next_locater, review_locater,
                           submit_locater, submit_application_locator]
                for i, button_locator in enumerate(buttons):
                    if is_present(button_locator):
                        button = self.wait.until(EC.element_to_be_clickable(button_locator))

                    if is_present(error_locator):
                        for element in self.browser.find_elements(error_locator[0],
                                                                  error_locator[1]):
                            text = element.text
                            if "Please enter a valid answer" in text:
                                button = None
                                break
                    if button:
                        button.click()
                        time.sleep(random.uniform(1.5, 2.5))
                        if i in (2, 3):
                            submitted = True
                        break
                if button == None:
                    log.info("Could not complete submission")
                    break
                elif submitted:
                    log.info("Application Submitted")
                    break

            time.sleep(random.uniform(1.5, 2.5))


        except Exception as e:
            log.info(e)
            log.info("cannot apply to this job")
            raise (e)

        return submitted

    def load_page(self, sleep=1):
        scroll_page = 0
        while scroll_page < 4000:
            self.browser.execute_script("window.scrollTo(0," + str(scroll_page) + " );")
            scroll_page += 200
            time.sleep(sleep)

        if sleep != 1:
            self.browser.execute_script("window.scrollTo(0,0);")
            time.sleep(sleep * 3)

        page = BeautifulSoup(self.browser.page_source, "lxml")
        return page

    def avoid_lock(self):
        x, _ = pyautogui.position()
        pyautogui.moveTo(x + 200, pyautogui.position().y, duration=1.0)
        pyautogui.moveTo(x, pyautogui.position().y, duration=0.5)
        pyautogui.keyDown('ctrl')
        pyautogui.press('esc')
        pyautogui.keyUp('ctrl')
        time.sleep(0.5)
        pyautogui.press('esc')

    def next_jobs_page(self, position, location, jobs_per_page):
        self.browser.get(
            "https://www.linkedin.com/jobs/search/?distance=100&f_AL=true&f_E=1%2C2&f_TPR=r2592000&f_WT=2%2C1%2C3&keywords=" +
            position + location + "&start=" + str(jobs_per_page))
        self.avoid_lock()
        log.info("Lock avoided.")
        self.load_page()
        return (self.browser, jobs_per_page)

    def finish_apply(self):
        self.browser.close()


if __name__ == '__main__':

    with open("config.yaml", 'r') as stream:
        try:
            parameters = yaml.safe_load(stream)
        except yaml.YAMLError as exc:
            raise exc

    assert len(parameters['positions']) > 0
    assert len(parameters['locations']) > 0
    assert parameters['username'] is not None
    assert parameters['password'] is not None

    if 'uploads' in parameters.keys() and type(parameters['uploads']) == list:
        raise Exception("uploads read from the config file appear to be in list format" +
                        " while should be dict. Try removing '-' from line containing" +
                        " filename & path")

    log.info({k: parameters[k] for k in parameters.keys() if k not in ['username', 'password']})

    output_filename = [f for f in parameters.get('output_filename', ['output.csv']) if f != None]
    output_filename = output_filename[0] if len(output_filename) > 0 else 'output.csv'
    blacklist = parameters.get('blacklist', [])
    blackListTitles = parameters.get('blackListTitles', [])
    keyword_list = parameters.get('keyword_list', [])

    uploads = {} if parameters.get('uploads', {}) == None else parameters.get('uploads', {})
    for key in uploads.keys():
        assert uploads[key] != None

    bot = EasyApplyBot(parameters['username'],
                       parameters['password'],
                       uploads=uploads,
                       filename=output_filename,
                       blacklist=blacklist,
                       blackListTitles=blackListTitles,
                       keyword_list=keyword_list
                       )

    locations = [l for l in parameters['locations'] if l != None]
    positions = [p for p in parameters['positions'] if p != None]
    bot.start_apply(positions, locations)
# Out:
# 00:38:35 - INFO - {'positions': ['Data Science', 'Machine Learning', 'Python'], 'locations': ['California'], 'uploads': {'Resume': 'C:\\Users\\trand\\OneDrive\\Desktop\\Darren_Tran_Resume.pdf'}, 'blackListTitles': ['AR', 'VR', 'Manager', 'Lead', 'Principal', 'Founding', 'Embedded', 'Java', 'Angular', 'Hadoop', 'MongDB', 'Spark', 'Ruby', 'Rails', 'Frontend', 'Designer', 'Azure', 'GCP', '.Net', '.NET', 'Senior', 'Sr.', 'Embedded', 'PHP', 'iOS', 'Android', 'Swift', 'Salesforce', 'Tableau', 'Mobile', 'Controls', 'API', 'C#', 'C++', 'C', 'Verification', 'Test', 'BI', 'Golang', 'TypeScript', 'Security', 'Network', 'Warehouse', 'Pipeline', 'Prototype', 'Client', 'Growth', 'Hacker', 'Unpaid', 'Report', 'Clearance', 'PhD', 'Minimum', 'Cybersecurity', 'Instructor', 'Teacher', 'Volunteer', 'Student', 'Sales', 'Web'], 'keyword_list': ['Python', 'Engineer', 'Developer', 'Researcher', 'Scientist', 'Programmer']}
# 00:38:35 - INFO - Welcome to Easy Apply Bot
# 00:38:35 - INFO - current directory is : C:\Users\trand\OneDrive\Desktop\Linkedin-Jobs
# 00:38:35 - INFO - 'utf-8' codec can't decode byte 0x96 in position 3456: invalid start byte   jobIDs could not be loaded from CSV output.csv
# 00:38:35 - INFO - Logging in.....Please wait :)
# C:\Users\trand\AppData\Local\Temp\ipykernel_26392\481434944.py:81: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   user_field = self.browser.find_element_by_id("username")
# C:\Users\trand\AppData\Local\Temp\ipykernel_26392\481434944.py:82: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   pw_field = self.browser.find_element_by_id("password")
# C:\Users\trand\AppData\Local\Temp\ipykernel_26392\481434944.py:83: DeprecationWarning: find_element_by_css_selector is deprecated. Please use find_element(by=By.CSS_SELECTOR, value=css_selector) instead
#   login_button = self.browser.find_element_by_css_selector(".btn__primary--large")
# 00:38:48 - INFO - Applying to Data Science: California
# 00:38:48 - INFO - Looking for jobs.. Please wait..
# 00:38:54 - INFO - Lock avoided.
# 00:39:14 - INFO - Looking for jobs.. Please wait..
# 00:39:14 - INFO - 719.0 minutes left in this search
# 00:39:14 - DEBUG - Sleeping for 4.5
# C:\Users\trand\AppData\Local\Temp\ipykernel_26392\481434944.py:142: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   scrollresults = self.browser.find_element_by_class_name(
# C:\Users\trand\AppData\Local\Temp\ipykernel_26392\481434944.py:152: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   links = self.browser.find_elements_by_xpath(
# C:\Users\trand\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webelement.py:426: UserWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   warnings.warn("find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead")
# C:\Users\trand\AppData\Local\Temp\ipykernel_26392\481434944.py:267: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   button = self.browser.find_elements_by_xpath(
# 00:39:58 - INFO - Clicking the EASY apply button
# 00:40:09 - INFO - Could not complete submission
# 00:40:11 - INFO -
# Position 1:
#  Bioinformatics Engineer | Netpace Inc | LinkedIn
#  * has Easy Apply Button
#
# 00:40:24 - INFO - Clicking the EASY apply button
# 00:40:37 - INFO - Could not complete submission
# 00:40:38 - INFO -
# Position 2:
#  Associate Engineer | AESC, Inc. | LinkedIn
#  * has Easy Apply Button
#
# 00:40:52 - INFO - Job title does not contain keywords
# 00:40:52 - INFO -
# Position 3:
#  Research Assistant | San Diego Association of Governments (SANDAG) | LinkedIn
#  * has Easy Apply Button
#
# 00:41:06 - INFO - Clicking the EASY apply button
# 00:41:17 - INFO - Application Submitted
# 00:41:19 - INFO -
# Position 4:
#  Entry Level Mission System Engineer | APR Consulting | LinkedIn
#  * has Easy Apply Button
#
# 00:41:32 - INFO - The button does not exist.
# 00:41:32 - INFO -
# Position 5:
#  Software Engineer (Front-End, React.js) | Cleanlab | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 00:41:45 - INFO - The button does not exist.
# 00:41:45 - INFO -
# Position 6:
#  Data Engineer | OnPoint Insights | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 00:41:59 - INFO - Job title does not contain keywords
# 00:41:59 - INFO -
# Position 7:
#  Two Postdoctoral Positions in (1) Interfacial and Colloidal Science and (2) Biointerfaces and Biophysics | University of California, Riverside | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 00:42:12 - INFO - The button does not exist.
# 00:42:12 - INFO -
# Position 8:
#  Python Developer | Magnus Technology Solutions | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 00:42:25 - INFO - The button does not exist.
# 00:42:25 - INFO -
# Position 9:
#  Data Engineer | GDK Services LLC | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 00:42:38 - INFO - The button does not exist.
# 00:42:38 - INFO -
# Position 10:
#  Data Engineer | e-Business International Inc | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 00:42:52 - INFO - The button does not exist.
# 00:42:52 - INFO -
# Position 11:
#  Solutions Engineer | Cogniac Corporation | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 00:43:05 - INFO - The button does not exist.
# 00:43:05 - INFO -
# Position 12:
#  System Analyst | Kutir Corporation | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 00:43:19 - INFO - The button does not exist.
# 00:43:19 - INFO -
# Position 13:
#  Data Analyst | TechTrueUp | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 00:43:32 - INFO - The button does not exist.
# 00:43:32 - INFO -
# Position 14:
#  Data Engineer | YASH Technologies | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 00:43:45 - INFO - The button does not exist.
# 00:43:46 - INFO -
# Position 15:
#  Data / API Engineer | PIT Solutions | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 00:43:58 - INFO - The button does not exist.
# 00:43:58 - INFO -
# Position 16:
#  Bioinformatics Engineer | Confidential | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 00:44:12 - INFO - The button does not exist.
# 00:44:12 - INFO -
# Position 17:
#  Python Developer | AltairTek | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 00:44:25 - INFO - The button does not exist.
# 00:44:25 - INFO -
# Position 18:
#  Data Engineer (Only USC and GC ) | Confidential | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 00:44:38 - INFO - The button does not exist.
# 00:44:38 - INFO -
# Position 19:
#  Data Engineer | Arreglo Consulting Inc. | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 00:44:51 - INFO - The button does not exist.
# 00:44:51 - INFO -
# Position 20:
#  Data Engineer | GDK Services LLC | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 00:45:04 - INFO - The button does not exist.
# 00:45:04 - INFO -
# Position 21:
#  Data Analyst | TechTrueUp | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 00:45:16 - INFO - The button does not exist.
# 00:45:16 - INFO -
# Position 22:
#  Artificial Intelligence Engineer | Donato Technologies, Inc. | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 00:45:29 - INFO - The button does not exist.
# 00:45:29 - INFO -
# Position 23:
#  MLOps Engineer / SRE / DevOps | Elemeno AI | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 00:45:42 - INFO - The button does not exist.
# 00:45:42 - INFO -
# Position 24:
#  Data Analyst | SGS Consulting | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 00:45:42 - INFO - ****************************************
#
#
#                     Going to next jobs page, YEAAAHHH!!
#                     ****************************************
#
#
# 00:45:50 - INFO - Lock avoided.
# 00:46:10 - INFO - 712.0 minutes left in this search
# 00:46:10 - DEBUG - Sleeping for 3.7
# 00:46:52 - INFO - The button does not exist.
# 00:46:52 - INFO -
# Position 26:
#  User Experience Engineer | Novus Labs | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 00:47:05 - INFO - The button does not exist.
# 00:47:05 - INFO -
# Position 27:
#  Data Analyst | InfoObjects Inc. | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 00:47:17 - INFO - The button does not exist.
# 00:47:17 - INFO -
# Position 28:
#  Embedded Software Engineer | ManpowerGroup | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 00:47:31 - INFO - The button does not exist.
# 00:47:31 - INFO -
# Position 29:
#  Data Engineer | Petra Tech, Inc. | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 00:47:43 - INFO - The button does not exist.
# 00:47:43 - INFO -
# Position 30:
#  Software Engineer | Cepton | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 00:47:56 - INFO - The button does not exist.
# 00:47:56 - INFO -
# Position 31:
#  Associate Engineer | AESC, Inc. | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 00:48:09 - INFO - The button does not exist.
# 00:48:09 - INFO -
# Position 32:
#  Data Engineer | Capio Group | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 00:48:09 - INFO - ****************************************
#
#
#                     Going to next jobs page, YEAAAHHH!!
#                     ****************************************
#
#
# 00:48:17 - INFO - Lock avoided.
# 00:48:37 - INFO - 710.0 minutes left in this search
# 00:48:37 - DEBUG - Sleeping for 3.5
# 00:49:18 - INFO - The button does not exist.
# 00:49:18 - INFO -
# Position 51:
#  Digital Process Specialist | Wiland | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 00:49:32 - INFO - The button does not exist.
# 00:49:32 - INFO -
# Position 52:
#  Google Analytics Implementation Specialist | Humans Doing | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 00:49:45 - INFO - The button does not exist.
# 00:49:45 - INFO -
# Position 53:
#  Statistical Programmer - Oncology (Ref: LM) | PHASTAR | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 00:49:58 - INFO - The button does not exist.
# 00:49:58 - INFO -
# Position 54:
#  Analytics Engineer | Spectraforce Technologies | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 00:50:10 - INFO - The button does not exist.
# 00:50:10 - INFO -
# Position 55:
#  Data Engineer | Revolution Technologies | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 00:50:10 - INFO - ****************************************
#
#
#                     Going to next jobs page, YEAAAHHH!!
#                     ****************************************
#
#
# 00:50:18 - INFO - Lock avoided.
# 00:50:38 - INFO - 708.0 minutes left in this search
# 00:50:38 - DEBUG - Sleeping for 4.4
# 00:51:20 - INFO - The button does not exist.
# 00:51:20 - INFO -
# Position 76:
#  Software Developer (Optanix) | ATSG | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 00:51:33 - INFO - The button does not exist.
# 00:51:33 - INFO -
# Position 77:
#  Data Engineer | Rangam | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 00:51:46 - INFO - The button does not exist.
# 00:51:46 - INFO -
# Position 78:
#  Data Analyst | Infogain | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 00:51:59 - INFO - The button does not exist.
# 00:51:59 - INFO -
# Position 79:
#  Java Developer | BuzzClan | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 00:52:12 - INFO - The button does not exist.
# 00:52:12 - INFO -
# Position 80:
#  Sr Data Analytics Engineer - TM1 - Remote | Harbor Freight Tools | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 00:52:25 - INFO - The button does not exist.
# 00:52:25 - INFO -
# Position 81:
#  Forecasting Intern - Summer 2022 (Flexible) | California ISO | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 00:52:38 - INFO - The button does not exist.
# 00:52:38 - INFO -
# Position 82:
#  Marketing Analytics Specialist | Growth Skills | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 00:52:38 - INFO - ****************************************
#
#
#                     Going to next jobs page, YEAAAHHH!!
#                     ****************************************
#
#
# 00:52:46 - INFO - Lock avoided.
# 00:53:06 - INFO - 705.0 minutes left in this search
# 00:53:06 - DEBUG - Sleeping for 3.7
# 00:53:48 - INFO - The button does not exist.
# 00:53:48 - INFO -
# Position 101:
#  Summer Health Data Science Intern | Genospace | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 00:54:01 - INFO - The button does not exist.
# 00:54:01 - INFO -
# Position 102:
#  Senior Data Scientist - Discovery | Nordstrom | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 00:54:14 - INFO - The button does not exist.
# 00:54:14 - INFO -
# Position 103:
#  Business Intelligence Specialist - Remote US | Transcend Digital | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 00:54:27 - INFO - The button does not exist.
# 00:54:27 - INFO -
# Position 104:
#  Data Scientist (Recent MS Grads) | Lucid Motors | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 00:54:40 - INFO - The button does not exist.
# 00:54:40 - INFO -
# Position 105:
#  Data Analyst | MetLife Legal Plans | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 00:54:53 - INFO - The button does not exist.
# 00:54:53 - INFO -
# Position 106:
#  Data Engineer | Engage3 | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 00:55:06 - INFO - The button does not exist.
# 00:55:06 - INFO -
# Position 107:
#  Analytics Engineer | Crunchyroll | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 00:55:06 - INFO - ****************************************
#
#
#                     Going to next jobs page, YEAAAHHH!!
#                     ****************************************
#
#
# 00:55:14 - INFO - Lock avoided.
# 00:55:34 - INFO - 703.0 minutes left in this search
# 00:55:34 - DEBUG - Sleeping for 4.4
# 00:56:17 - INFO - The button does not exist.
# 00:56:17 - INFO -
# Position 126:
#  Junior Data Scientist - EV Charging | CyberCoders | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 00:56:30 - INFO - The button does not exist.
# 00:56:30 - INFO -
# Position 127:
#  Staff Specialist | Poshmark | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 00:56:43 - INFO - The button does not exist.
# 00:56:43 - INFO -
# Position 128:
#  Data Engineer, ML Platform | Change.org | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 00:56:56 - INFO - The button does not exist.
# 00:56:56 - INFO -
# Position 129:
#  Software Engineer | Human Longevity, Inc. | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 00:57:09 - INFO - The button does not exist.
# 00:57:09 - INFO -
# Position 130:
#  AE/Sales Director (Government) (Upto $150k + commission) | CareerWellness | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 00:57:22 - INFO - The button does not exist.
# 00:57:22 - INFO -
# Position 131:
#  Data Engineer | Genesis Capital Group | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 00:57:22 - INFO - ****************************************
#
#
#                     Going to next jobs page, YEAAAHHH!!
#                     ****************************************
#
#
# 00:57:30 - INFO - Lock avoided.
# 00:57:50 - INFO - 700.0 minutes left in this search
# 00:57:50 - DEBUG - Sleeping for 3.8
# 00:58:32 - INFO - The button does not exist.
# 00:58:32 - INFO -
# Position 151:
#  Business Analyst | SIS - Strategic Innovative Solutions | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 00:58:45 - INFO - The button does not exist.
# 00:58:45 - INFO -
# Position 152:
#  Junior Research Associate | Center for Sustainable Energy (CSE) | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 00:58:58 - INFO - The button does not exist.
# 00:58:58 - INFO -
# Position 153:
#  RSi Applications Consultant / Report Developer | IRI | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 00:59:11 - INFO - The button does not exist.
# 00:59:11 - INFO -
# Position 154:
#  Computational Chemist - Structure-Based Drug Design | CyberCoders | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 00:59:24 - INFO - The button does not exist.
# 00:59:24 - INFO -
# Position 155:
#  ESG Data Analyst | Verdani Partners | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 00:59:37 - INFO - The button does not exist.
# 00:59:37 - INFO -
# Position 156:
#  Data Value Engineer- Finance Sector | MANTA - Unified Lineage Platform | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 00:59:50 - INFO - The button does not exist.
# 00:59:50 - INFO -
# Position 157:
#  Computational Engineer (P-2224) | 10x Genomics | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 00:59:50 - INFO - ****************************************
#
#
#                     Going to next jobs page, YEAAAHHH!!
#                     ****************************************
#
#
# 00:59:57 - INFO - Lock avoided.
# 01:00:18 - INFO - 698.0 minutes left in this search
# 01:00:18 - DEBUG - Sleeping for 4.8
# 01:00:47 - INFO - Applying to Machine Learning: California
# 01:00:47 - INFO - Looking for jobs.. Please wait..
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Input In [3], in <cell line: 392>()
#     431 locations = [l for l in parameters['locations'] if l != None]
#     432 positions = [p for p in parameters['positions'] if p != None]
# --> 433 bot.start_apply(positions, locations)
#
# Input In [3], in EasyApplyBot.start_apply(self, positions, locations)
#     109     log.info(f"Applying to {position}: {location}")
#     110     location = "&location=" + location
# --> 111     self.applications_loop(position, location)
#     112 if len(combos) > 500:
#     113     break
#
# Input In [3], in EasyApplyBot.applications_loop(self, position, location)
#     122 start_time = time.time()
#     124 log.info("Looking for jobs.. Please wait..")
# --> 126 self.browser.set_window_position(0, 0)
#     127 self.browser.maximize_window()
#     128 self.browser, _ = self.next_jobs_page(position, location, jobs_per_page)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py:1422, in WebDriver.set_window_position(self, x, y, windowHandle)
#    1420 if windowHandle != 'current':
#    1421     warnings.warn("Only 'current' window is supported for W3C compatible browsers.")
# -> 1422 return self.set_window_rect(x=int(x), y=int(y))
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py:1470, in WebDriver.set_window_rect(self, x, y, width, height)
#    1467 if (x is None and y is None) and (not height and not width):
#    1468     raise InvalidArgumentException("x and y or height and width need values")
# -> 1470 return self.execute(Command.SET_WINDOW_RECT, {"x": x, "y": y,
#    1471                                               "width": width,
#    1472                                               "height": height})['value']
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py:425, in WebDriver.execute(self, driver_command, params)
#     423 response = self.command_executor.execute(driver_command, params)
#     424 if response:
# --> 425     self.error_handler.check_response(response)
#     426     response['value'] = self._unwrap_value(
#     427         response.get('value', None))
#     428     return response
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\errorhandler.py:247, in ErrorHandler.check_response(self, response)
#     245         alert_text = value['alert'].get('text')
#     246     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247 raise exception_class(message, screen, stacktrace)
#
# WebDriverException: Message: unknown error: failed to change window state to 'normal', current state is 'maximized'
#   (Session info: chrome=101.0.4951.67)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x0026B8F3+2406643]
# 	Ordinal0 [0x001FAF31+1945393]
# 	Ordinal0 [0x000EC748+837448]
# 	Ordinal0 [0x000D705C+749660]
# 	Ordinal0 [0x000D5FC1+745409]
# 	Ordinal0 [0x000D6A2C+748076]
# 	Ordinal0 [0x00154470+1262704]
# 	Ordinal0 [0x0013427C+1131132]
# 	Ordinal0 [0x00144682+1197698]
# 	Ordinal0 [0x00134096+1130646]
# 	Ordinal0 [0x0010E636+976438]
# 	Ordinal0 [0x0010F546+980294]
# 	GetHandleVerifier [0x004D9612+2498066]
# 	GetHandleVerifier [0x004CC920+2445600]
# 	GetHandleVerifier [0x00304F2A+579370]
# 	GetHandleVerifier [0x00303D36+574774]
# 	Ordinal0 [0x00201C0B+1973259]
# 	Ordinal0 [0x00206688+1992328]
# 	Ordinal0 [0x00206775+1992565]
# 	Ordinal0 [0x0020F8D1+2029777]
# 	BaseThreadInitThunk [0x76016739+25]
# 	RtlGetFullPathName_UEx [0x773E8FEF+1215]
# 	RtlGetFullPathName_UEx [0x773E8FBD+1165]
# 	(No symbol) [0x00000000]

# %%
def setupLogger():
    dt = datetime.strftime(datetime.now(), "%m_%d_%y %H_%M_%S ")

    if not os.path.isdir('./logs'):
        os.mkdir('./logs')

    # TODO need to check if there is a log dir available or not
    logging.basicConfig(filename=('./logs/' + str(dt) + 'applyJobs.log'), filemode='w',
                        format='%(asctime)s::%(name)s::%(levelname)s::%(message)s', datefmt='./logs/%d-%b-%y %H:%M:%S')
    log.setLevel(logging.DEBUG)
    c_handler = logging.StreamHandler()
    c_handler.setLevel(logging.DEBUG)
    c_format = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s', '%H:%M:%S')
    c_handler.setFormatter(c_format)
    log.addHandler(c_handler)


class EasyApplyBot:
    setupLogger()
    # MAX_SEARCH_TIME is 10 hours by default, feel free to modify it
    MAX_SEARCH_TIME = 12 * 60 * 60

    def __init__(self,
                 username,
                 password,
                 uploads={},
                 filename='output.csv',
                 blacklist=[],
                 blackListTitles=[],
                 keyword_list=[]):

        log.info("Welcome to Easy Apply Bot")
        dirpath = os.getcwd()
        log.info("current directory is : " + dirpath)

        self.uploads = uploads
        past_ids = self.get_appliedIDs(filename)
        self.appliedJobIDs = past_ids if past_ids != None else []
        self.filename = filename
        self.options = self.browser_options()
        self.browser = driver
        self.wait = WebDriverWait(self.browser, 30)
        self.blacklist = blacklist
        self.blackListTitles = blackListTitles
        self.keyword_list = keyword_list
        self.start_linkedin(username, password)

    def get_appliedIDs(self, filename):
        try:
            df = pd.read_csv(filename,
                             header=None,
                             names=['timestamp', 'jobID', 'job', 'company', 'attempted', 'result'],
                             lineterminator='\n',
                             encoding='utf-8')

            df['timestamp'] = pd.to_datetime(df['timestamp'], format="%Y-%m-%d %H:%M:%S")
            df = df[df['timestamp'] > (datetime.now() - timedelta(days=2))]
            jobIDs = list(df.jobID)
            log.info(f"{len(jobIDs)} jobIDs found")
            return jobIDs
        except Exception as e:
            log.info(str(e) + "   jobIDs could not be loaded from CSV {}".format(filename))
            return None

    def browser_options(self):
        options = Options()
        options.add_argument("--start-maximized")
        options.add_argument("--ignore-certificate-errors")
        options.add_argument('--no-sandbox')
        options.add_argument("--disable-extensions")

        # Disable webdriver flags or you will be easily detectable
        options.add_argument("--disable-blink-features")
        options.add_argument("--disable-blink-features=AutomationControlled")
        return options

    def start_linkedin(self, username, password):
        log.info("Logging in.....Please wait :)  ")
        self.browser.get("https://www.linkedin.com/login?trk=guest_homepage-basic_nav-header-signin")
        try:
            user_field = self.browser.find_element_by_id("username")
            pw_field = self.browser.find_element_by_id("password")
            login_button = self.browser.find_element_by_css_selector(".btn__primary--large")
            user_field.send_keys(username)
            user_field.send_keys(Keys.TAB)
            time.sleep(2)
            pw_field.send_keys(password)
            time.sleep(2)
            login_button.click()
            time.sleep(3)
        except TimeoutException:
            log.info("TimeoutException! Username/password field or login button not found")

    def fill_data(self):
        self.browser.set_window_size(100, 100)
        self.browser.set_window_position(2000, 2000)

    def start_apply(self, positions, locations):
        start = time.time()
        self.fill_data()

        combos = []
        while len(combos) < len(positions) * len(locations):
            position = positions[random.randint(0, len(positions) - 1)]
            location = locations[random.randint(0, len(locations) - 1)]
            combo = (position, location)
            if combo not in combos:
                combos.append(combo)
                log.info(f"Applying to {position}: {location}")
                location = "&location=" + location
                self.applications_loop(position, location)
            if len(combos) > 500:
                break

    # self.finish_apply() --> this does seem to cause more harm than good, since it closes the browser which we usually don't want, other conditions will stop the loop and just break out

    def applications_loop(self, position, location):

        count_application = 0
        count_job = 0
        jobs_per_page = 0
        start_time = time.time()

        log.info("Looking for jobs.. Please wait..")

        self.browser.set_window_position(0, 0)
        self.browser.maximize_window()
        self.browser, _ = self.next_jobs_page(position, location, jobs_per_page)
        log.info("Looking for jobs.. Please wait..")

        while time.time() - start_time < self.MAX_SEARCH_TIME:
            log.info(f"{(self.MAX_SEARCH_TIME - (time.time() - start_time)) // 60} minutes left in this search")

            # sleep to make sure everything loads, add random to make us look human.
            randoTime = random.uniform(3.5, 4.9)
            log.debug(f"Sleeping for {round(randoTime, 1)}")
            time.sleep(randoTime)
            self.load_page(sleep=1)

            # LinkedIn displays the search results in a scrollable <div> on the left side, we have to scroll to its bottom

            scrollresults = self.browser.find_element_by_class_name(
                "jobs-search-results"
            )
            # Selenium only detects visible elements; if we scroll to the bottom too fast, only 8-9 results will be loaded into IDs list
            for i in range(300, 3000, 100):
                self.browser.execute_script("arguments[0].scrollTo(0, {})".format(i), scrollresults)

            time.sleep(4)

            # get job links
            links = self.browser.find_elements_by_xpath(
                '//div[@data-job-id]'
            )

            if len(links) == 0:
                break

            # get job ID of each job link
            IDs = []
            for link in links:
                children = link.find_elements_by_xpath(
                    './/a[@data-control-name]'
                )
                for child in children:
                    if child.text not in self.blacklist:
                        temp = link.get_attribute("data-job-id")
                        jobID = temp.split(":")[-1]
                        IDs.append(int(jobID))
            IDs = set(IDs)

            # remove already applied jobs
            before = len(IDs)
            jobIDs = [x for x in IDs if x not in self.appliedJobIDs]
            after = len(jobIDs)

            # it assumed that 25 jobs are listed in the results window
            if len(jobIDs) == 0 and len(IDs) > 23:
                jobs_per_page = jobs_per_page + 25
                count_job = 0
                self.avoid_lock()
                self.browser, jobs_per_page = self.next_jobs_page(position,
                                                                  location,
                                                                  jobs_per_page)
            # loop over IDs to apply
            for i, jobID in enumerate(jobIDs):
                count_job += 1
                self.get_job_page(jobID)

                # get easy apply button
                button = self.get_easy_apply_button()
                # word filter to skip positions not wanted
                
                if button is not False:
                    if any(word in self.browser.title.split(" ") for word in blackListTitles):
                        log.info('skipping this application, a blacklisted keyword was found in the job position')
                        string_easy = "* Contains blacklisted keyword"
                        result = False
                    elif any(word in self.browser.title.split(" ") for word in keyword_list):
                        string_easy = "* has Easy Apply Button"
                        log.info("Clicking the EASY apply button")
                        button.click()
                        time.sleep(3)
                        result = self.send_resume()
                        count_application += 1
                    else:
                        log.info('Job title does not contain keywords')
                        result = False
                else:
                    log.info("The button does not exist.")
                    string_easy = "* Doesn't have Easy Apply Button"
                    result = False

                position_number = str(count_job + jobs_per_page)
                log.info(f"\nPosition {position_number}:\n {self.browser.title} \n {string_easy} \n")

                self.write_to_file(button, jobID, self.browser.title, result)

                # sleep every 20 applications
                if count_application != 0 and count_application % 20 == 0:
                    sleepTime = random.randint(500, 900)
                    log.info(f"""********count_application: {count_application}************\n\n
                                Time for a nap - see you in:{int(sleepTime / 60)} min
                            ****************************************\n\n""")
                    time.sleep(sleepTime)

                # go to new page if all jobs are done
                if count_job == len(jobIDs):
                    jobs_per_page = jobs_per_page + 25
                    count_job = 0
                    log.info("""****************************************\n\n
                    Going to next jobs page, YEAAAHHH!!
                    ****************************************\n\n""")
                    self.avoid_lock()
                    self.browser, jobs_per_page = self.next_jobs_page(position,
                                                                      location,
                                                                      jobs_per_page)
        # if len(jobIDs) == 0 or i == (len(jobIDs) - 1):
        # break

    def write_to_file(self, button, jobID, browserTitle, result):
        def re_extract(text, pattern):
            target = re.search(pattern, text)
            if target:
                target = target.group(1)
            return target

        timestamp = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
        attempted = False if button == False else True
        job = re_extract(browserTitle.split(' | ')[0], r"\(?\d?\)?\s?(\w.*)")
        company = re_extract(browserTitle.split(' | ')[1], r"(\w.*)")

        toWrite = [timestamp, jobID, job, company, attempted, result]
        with open(self.filename, 'a') as f:
            writer = csv.writer(f)
            writer.writerow(toWrite)

    def get_job_page(self, jobID):

        job = 'https://www.linkedin.com/jobs/view/' + str(jobID)
        self.browser.get(job)
        self.job_page = self.load_page(sleep=0.5)
        return self.job_page

    def get_easy_apply_button(self):
        try:
            button = self.browser.find_elements_by_xpath(
                '//button[contains(@class, "jobs-apply")]/span[1]'
            )

            EasyApplyButton = button[0]
        except:
            EasyApplyButton = False

        return EasyApplyButton

    def send_resume(self):
        def is_present(button_locator):
            return len(self.browser.find_elements(button_locator[0],
                                                  button_locator[1])) > 0

        try:
            time.sleep(random.uniform(1.5, 2.5))
            next_locater = (By.CSS_SELECTOR,
                            "button[aria-label='Continue to next step']")
            review_locater = (By.CSS_SELECTOR,
                              "button[aria-label='Review your application']")
            submit_locater = (By.CSS_SELECTOR,
                              "button[aria-label='Submit application']")
            submit_application_locator = (By.CSS_SELECTOR,
                                          "button[aria-label='Submit application']")
            error_locator = (By.CSS_SELECTOR,
                             "p[data-test-form-element-error-message='true']")
            upload_locator = (By.CSS_SELECTOR, "input[name='file']")

            submitted = False
            while True:

                # Upload Cover Letter if possible
                if is_present(upload_locator):

                    input_buttons = self.browser.find_elements(upload_locator[0],
                                                               upload_locator[1])
                    for input_button in input_buttons:
                        parent = input_button.find_element(By.XPATH, "..")
                        sibling = parent.find_element(By.XPATH, "preceding-sibling::*")
                        grandparent = sibling.find_element(By.XPATH, "..")
                        for key in self.uploads.keys():
                            sibling_text = sibling.text
                            gparent_text = grandparent.text
                            if key.lower() in sibling_text.lower() or key in gparent_text.lower():
                                input_button.send_keys(self.uploads[key])

                    # input_button[0].send_keys(self.cover_letter_loctn)
                    time.sleep(random.uniform(4.5, 6.5))

                # Click Next or submitt button if possible
                button = None
                buttons = [next_locater, review_locater,
                           submit_locater, submit_application_locator]
                for i, button_locator in enumerate(buttons):
                    if is_present(button_locator):
                        button = self.wait.until(EC.element_to_be_clickable(button_locator))

                    if is_present(error_locator):
                        for element in self.browser.find_elements(error_locator[0],
                                                                  error_locator[1]):
                            text = element.text
                            if "Please enter a valid answer" in text:
                                button = None
                                break
                    if button:
                        button.click()
                        time.sleep(random.uniform(1.5, 2.5))
                        if i in (2, 3):
                            submitted = True
                        break
                if button == None:
                    log.info("Could not complete submission")
                    break
                elif submitted:
                    log.info("Application Submitted")
                    break

            time.sleep(random.uniform(1.5, 2.5))


        except Exception as e:
            log.info(e)
            log.info("cannot apply to this job")
            raise (e)

        return submitted

    def load_page(self, sleep=1):
        scroll_page = 0
        while scroll_page < 4000:
            self.browser.execute_script("window.scrollTo(0," + str(scroll_page) + " );")
            scroll_page += 200
            time.sleep(sleep)

        if sleep != 1:
            self.browser.execute_script("window.scrollTo(0,0);")
            time.sleep(sleep * 3)

        page = BeautifulSoup(self.browser.page_source, "lxml")
        return page

    def avoid_lock(self):
        x, _ = pyautogui.position()
        pyautogui.moveTo(x + 200, pyautogui.position().y, duration=1.0)
        pyautogui.moveTo(x, pyautogui.position().y, duration=0.5)
        pyautogui.keyDown('ctrl')
        pyautogui.press('esc')
        pyautogui.keyUp('ctrl')
        time.sleep(0.5)
        pyautogui.press('esc')

    def next_jobs_page(self, position, location, jobs_per_page):
        self.browser.get(
            "https://www.linkedin.com/jobs/search/?distance=100&f_AL=true&f_E=1%2C2&f_TPR=r2592000&f_WT=2%2C1%2C3&keywords=" +
            position + location + "&start=" + str(jobs_per_page))
        self.avoid_lock()
        log.info("Lock avoided.")
        self.load_page()
        return (self.browser, jobs_per_page)

    def finish_apply(self):
        self.browser.close()


if __name__ == '__main__':

    with open("config.yaml", 'r') as stream:
        try:
            parameters = yaml.safe_load(stream)
        except yaml.YAMLError as exc:
            raise exc

    assert len(parameters['positions']) > 0
    assert len(parameters['locations']) > 0
    assert parameters['username'] is not None
    assert parameters['password'] is not None

    if 'uploads' in parameters.keys() and type(parameters['uploads']) == list:
        raise Exception("uploads read from the config file appear to be in list format" +
                        " while should be dict. Try removing '-' from line containing" +
                        " filename & path")

    log.info({k: parameters[k] for k in parameters.keys() if k not in ['username', 'password']})

    output_filename = [f for f in parameters.get('output_filename', ['output.csv']) if f != None]
    output_filename = output_filename[0] if len(output_filename) > 0 else 'output.csv'
    blacklist = parameters.get('blacklist', [])
    blackListTitles = parameters.get('blackListTitles', [])
    keyword_list = parameters.get('keyword_list', [])

    uploads = {} if parameters.get('uploads', {}) == None else parameters.get('uploads', {})
    for key in uploads.keys():
        assert uploads[key] != None

    bot = EasyApplyBot(parameters['username'],
                       parameters['password'],
                       uploads=uploads,
                       filename=output_filename,
                       blacklist=blacklist,
                       blackListTitles=blackListTitles,
                       keyword_list=keyword_list
                       )

    locations = [l for l in parameters['locations'] if l != None]
    positions = [p for p in parameters['positions'] if p != None]
    bot.start_apply(positions, locations)
# Out:
# 04:48:31 - INFO - {'positions': ['Data Science', 'Machine Learning', 'Python'], 'locations': ['California'], 'uploads': {'Resume': 'C:\\Users\\trand\\OneDrive\\Desktop\\Darren_Tran_Resume.pdf'}, 'blackListTitles': ['AR', 'VR', 'Manager', 'Lead', 'Principal', 'Founding', 'Embedded', 'Java', 'Angular', 'Hadoop', 'MongDB', 'Spark', 'Ruby', 'Rails', 'Frontend', 'Designer', 'Azure', 'GCP', '.Net', '.NET', 'Senior', 'Sr.', 'Embedded', 'PHP', 'iOS', 'Android', 'Swift', 'Salesforce', 'Tableau', 'Mobile', 'Controls', 'API', 'C#', 'C++', 'C', 'Verification', 'Test', 'BI', 'Golang', 'TypeScript', 'Security', 'Network', 'Warehouse', 'Pipeline', 'Prototype', 'Client', 'Growth', 'Hacker', 'Unpaid', 'Report', 'Clearance', 'PhD', 'Minimum', 'Cybersecurity', 'Instructor', 'Teacher', 'Volunteer', 'Student', 'Sales', 'Web'], 'keyword_list': ['Python', 'Engineer', 'Developer', 'Researcher', 'Scientist', 'Programmer']}
# 04:48:31 - INFO - {'positions': ['Data Science', 'Machine Learning', 'Python'], 'locations': ['California'], 'uploads': {'Resume': 'C:\\Users\\trand\\OneDrive\\Desktop\\Darren_Tran_Resume.pdf'}, 'blackListTitles': ['AR', 'VR', 'Manager', 'Lead', 'Principal', 'Founding', 'Embedded', 'Java', 'Angular', 'Hadoop', 'MongDB', 'Spark', 'Ruby', 'Rails', 'Frontend', 'Designer', 'Azure', 'GCP', '.Net', '.NET', 'Senior', 'Sr.', 'Embedded', 'PHP', 'iOS', 'Android', 'Swift', 'Salesforce', 'Tableau', 'Mobile', 'Controls', 'API', 'C#', 'C++', 'C', 'Verification', 'Test', 'BI', 'Golang', 'TypeScript', 'Security', 'Network', 'Warehouse', 'Pipeline', 'Prototype', 'Client', 'Growth', 'Hacker', 'Unpaid', 'Report', 'Clearance', 'PhD', 'Minimum', 'Cybersecurity', 'Instructor', 'Teacher', 'Volunteer', 'Student', 'Sales', 'Web'], 'keyword_list': ['Python', 'Engineer', 'Developer', 'Researcher', 'Scientist', 'Programmer']}
# 04:48:31 - INFO - Welcome to Easy Apply Bot
# 04:48:31 - INFO - Welcome to Easy Apply Bot
# 04:48:31 - INFO - current directory is : C:\Users\trand\OneDrive\Desktop\Linkedin-Jobs
# 04:48:31 - INFO - current directory is : C:\Users\trand\OneDrive\Desktop\Linkedin-Jobs
# 04:48:31 - INFO - 'utf-8' codec can't decode byte 0x96 in position 3456: invalid start byte   jobIDs could not be loaded from CSV output.csv
# 04:48:31 - INFO - 'utf-8' codec can't decode byte 0x96 in position 3456: invalid start byte   jobIDs could not be loaded from CSV output.csv
# 04:48:31 - INFO - Logging in.....Please wait :)
# 04:48:31 - INFO - Logging in.....Please wait :)
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Input In [4], in <cell line: 392>()
#     419 for key in uploads.keys():
#     420     assert uploads[key] != None
# --> 422 bot = EasyApplyBot(parameters['username'],
#     423                    parameters['password'],
#     424                    uploads=uploads,
#     425                    filename=output_filename,
#     426                    blacklist=blacklist,
#     427                    blackListTitles=blackListTitles,
#     428                    keyword_list=keyword_list
#     429                    )
#     431 locations = [l for l in parameters['locations'] if l != None]
#     432 positions = [p for p in parameters['positions'] if p != None]
#
# Input In [4], in EasyApplyBot.__init__(self, username, password, uploads, filename, blacklist, blackListTitles, keyword_list)
#      44 self.blackListTitles = blackListTitles
#      45 self.keyword_list = keyword_list
# ---> 46 self.start_linkedin(username, password)
#
# Input In [4], in EasyApplyBot.start_linkedin(self, username, password)
#      77 def start_linkedin(self, username, password):
#      78     log.info("Logging in.....Please wait :)  ")
# ---> 79     self.browser.get("https://www.linkedin.com/login?trk=guest_homepage-basic_nav-header-signin")
#      80     try:
#      81         user_field = self.browser.find_element_by_id("username")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py:437, in WebDriver.get(self, url)
#     433 def get(self, url: str) -> None:
#     434     """
#     435     Loads a web page in the current browser session.
#     436     """
# --> 437     self.execute(Command.GET, {'url': url})
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py:425, in WebDriver.execute(self, driver_command, params)
#     423 response = self.command_executor.execute(driver_command, params)
#     424 if response:
# --> 425     self.error_handler.check_response(response)
#     426     response['value'] = self._unwrap_value(
#     427         response.get('value', None))
#     428     return response
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\errorhandler.py:247, in ErrorHandler.check_response(self, response)
#     245         alert_text = value['alert'].get('text')
#     246     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247 raise exception_class(message, screen, stacktrace)
#
# WebDriverException: Message: chrome not reachable
#   (Session info: chrome=101.0.4951.67)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x0026B8F3+2406643]
# 	Ordinal0 [0x001FAF31+1945393]
# 	Ordinal0 [0x000EC610+837136]
# 	Ordinal0 [0x000E0442+787522]
# 	Ordinal0 [0x000E0C78+789624]
# 	Ordinal0 [0x000E24B2+795826]
# 	Ordinal0 [0x000DBF09+769801]
# 	Ordinal0 [0x000EDAC0+842432]
# 	Ordinal0 [0x00143E62+1195618]
# 	Ordinal0 [0x00134096+1130646]
# 	Ordinal0 [0x0010E636+976438]
# 	Ordinal0 [0x0010F546+980294]
# 	GetHandleVerifier [0x004D9612+2498066]
# 	GetHandleVerifier [0x004CC920+2445600]
# 	GetHandleVerifier [0x00304F2A+579370]
# 	GetHandleVerifier [0x00303D36+574774]
# 	Ordinal0 [0x00201C0B+1973259]
# 	Ordinal0 [0x00206688+1992328]
# 	Ordinal0 [0x00206775+1992565]
# 	Ordinal0 [0x0020F8D1+2029777]
# 	BaseThreadInitThunk [0x76016739+25]
# 	RtlGetFullPathName_UEx [0x773E8FEF+1215]
# 	RtlGetFullPathName_UEx [0x773E8FBD+1165]
# 	(No symbol) [0x00000000]
