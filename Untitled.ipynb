# %%
pip install -r requirements.txt
# Out:
# Collecting selenium
#   Using cached selenium-4.1.5-py3-none-any.whl (979 kB)
# Requirement already satisfied: beautifulsoup4 in c:\users\trand\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from -r requirements.txt (line 2)) (4.11.1)
# Collecting pandas
#   Using cached pandas-1.4.2-cp39-cp39-win_amd64.whl (10.5 MB)
# Collecting pyautogui
#   Using cached PyAutoGUI-0.9.53-py3-none-any.whl
# Collecting webdriver_manager
#   Using cached webdriver_manager-3.5.4-py2.py3-none-any.whl (18 kB)
# Collecting PyYAML
#   Using cached PyYAML-6.0-cp39-cp39-win_amd64.whl (151 kB)
# Collecting lxml
#   Using cached lxml-4.8.0-cp39-cp39-win_amd64.whl (3.6 MB)
# Requirement already satisfied: urllib3[secure,socks]~=1.26 in c:\users\trand\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from selenium->-r requirements.txt (line 1)) (1.26.9)
# Collecting trio-websocket~=0.9
#   Using cached trio_websocket-0.9.2-py3-none-any.whl (16 kB)
# Collecting trio~=0.17
#   Using cached trio-0.20.0-py3-none-any.whl (359 kB)
# Requirement already satisfied: soupsieve>1.2 in c:\users\trand\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from beautifulsoup4->-r requirements.txt (line 2)) (2.3.2.post1)
# Collecting numpy>=1.18.5
#   Using cached numpy-1.22.3-cp39-cp39-win_amd64.whl (14.7 MB)
# Requirement already satisfied: pytz>=2020.1 in c:\users\trand\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas->-r requirements.txt (line 3)) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\trand\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas->-r requirements.txt (line 3)) (2.8.2)
# Collecting pyscreeze>=0.1.21
#   Using cached PyScreeze-0.1.28-py3-none-any.whl
# Collecting mouseinfo
#   Using cached MouseInfo-0.1.3-py3-none-any.whl
# Collecting pymsgbox
#   Using cached PyMsgBox-1.0.9-py3-none-any.whl
# Collecting PyTweening>=1.0.1
#   Using cached pytweening-1.0.4-py3-none-any.whl
# Collecting pygetwindow>=0.0.5
#   Using cached PyGetWindow-0.0.9-py3-none-any.whl
# Requirement already satisfied: requests in c:\users\trand\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from webdriver_manager->-r requirements.txt (line 5)) (2.27.1)
# Collecting pyrect
#   Using cached PyRect-0.2.0-py2.py3-none-any.whl
# Requirement already satisfied: six>=1.5 in c:\users\trand\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from python-dateutil>=2.8.1->pandas->-r requirements.txt (line 3)) (1.16.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\trand\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from trio~=0.17->selenium->-r requirements.txt (line 1)) (1.15.0)
# Collecting async-generator>=1.9
#   Using cached async_generator-1.10-py3-none-any.whl (18 kB)
# Requirement already satisfied: sniffio in c:\users\trand\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from trio~=0.17->selenium->-r requirements.txt (line 1)) (1.2.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\trand\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from trio~=0.17->selenium->-r requirements.txt (line 1)) (21.4.0)
# Collecting sortedcontainers
#   Using cached sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Collecting outcome
#   Using cached outcome-1.1.0-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: idna in c:\users\trand\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from trio~=0.17->selenium->-r requirements.txt (line 1)) (3.3)
# Collecting wsproto>=0.14
#   Using cached wsproto-1.1.0-py3-none-any.whl (24 kB)
# Collecting PySocks!=1.5.7,<2.0,>=1.5.6
#   Using cached PySocks-1.7.1-py3-none-any.whl (16 kB)
# Requirement already satisfied: certifi in c:\users\trand\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from urllib3[secure,socks]~=1.26->selenium->-r requirements.txt (line 1)) (2021.10.8)
# Collecting pyOpenSSL>=0.14
#   Using cached pyOpenSSL-22.0.0-py2.py3-none-any.whl (55 kB)
# Collecting cryptography>=1.3.4
#   Using cached cryptography-37.0.2-cp36-abi3-win_amd64.whl (2.4 MB)
# Collecting pyperclip
#   Using cached pyperclip-1.8.2-py3-none-any.whl
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\trand\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from requests->webdriver_manager->-r requirements.txt (line 5)) (2.0.12)
# Requirement already satisfied: pycparser in c:\users\trand\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from cffi>=1.14->trio~=0.17->selenium->-r requirements.txt (line 1)) (2.21)
# Collecting h11<1,>=0.9.0
#   Using cached h11-0.13.0-py3-none-any.whl (58 kB)
# Installing collected packages: sortedcontainers, PyTweening, pyscreeze, pyrect, pyperclip, pymsgbox, PyYAML, PySocks, pygetwindow, outcome, numpy, mouseinfo, lxml, h11, async-generator, wsproto, webdriver_manager, trio, pyautogui, pandas, cryptography, trio-websocket, pyOpenSSL, selenium
# Successfully installed PySocks-1.7.1 PyTweening-1.0.4 PyYAML-6.0 async-generator-1.10 cryptography-37.0.2 h11-0.13.0 lxml-4.8.0 mouseinfo-0.1.3 numpy-1.22.3 outcome-1.1.0 pandas-1.4.2 pyOpenSSL-22.0.0 pyautogui-0.9.53 pygetwindow-0.0.9 pymsgbox-1.0.9 pyperclip-1.8.2 pyrect-0.2.0 pyscreeze-0.1.28 selenium-4.1.5 sortedcontainers-2.4.0 trio-0.20.0 trio-websocket-0.9.2 webdriver_manager-3.5.4 wsproto-1.1.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 22.1 is available.
# You should consider upgrading via the 'C:\Users\trand\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.

# %%
import time, random, os, csv, platform
import logging
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.common.exceptions import TimeoutException
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from bs4 import BeautifulSoup
import pandas as pd
import pyautogui

from urllib.request import urlopen
from webdriver_manager.chrome import ChromeDriverManager
import re
import yaml
from datetime import datetime, timedelta

log = logging.getLogger(__name__)
driver = webdriver.Chrome(ChromeDriverManager().install())


def setupLogger():
    dt = datetime.strftime(datetime.now(), "%m_%d_%y %H_%M_%S ")

    if not os.path.isdir('./logs'):
        os.mkdir('./logs')

    # TODO need to check if there is a log dir available or not
    logging.basicConfig(filename=('./logs/' + str(dt) + 'applyJobs.log'), filemode='w',
                        format='%(asctime)s::%(name)s::%(levelname)s::%(message)s', datefmt='./logs/%d-%b-%y %H:%M:%S')
    log.setLevel(logging.DEBUG)
    c_handler = logging.StreamHandler()
    c_handler.setLevel(logging.DEBUG)
    c_format = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s', '%H:%M:%S')
    c_handler.setFormatter(c_format)
    log.addHandler(c_handler)


class EasyApplyBot:
    setupLogger()
    # MAX_SEARCH_TIME is 10 hours by default, feel free to modify it
    MAX_SEARCH_TIME = 12 * 60 * 60

    def __init__(self,
                 username,
                 password,
                 uploads={},
                 filename='output.csv',
                 blacklist=[],
                 blackListTitles=[],
                 keyword_list=[]):

        log.info("Welcome to Easy Apply Bot")
        dirpath = os.getcwd()
        log.info("current directory is : " + dirpath)

        self.uploads = uploads
        past_ids = self.get_appliedIDs(filename)
        self.appliedJobIDs = past_ids if past_ids != None else []
        self.filename = filename
        self.options = self.browser_options()
        self.browser = driver
        self.wait = WebDriverWait(self.browser, 30)
        self.blacklist = blacklist
        self.blackListTitles = blackListTitles
        self.keyword_list = keyword_list
        self.start_linkedin(username, password)

    def get_appliedIDs(self, filename):
        try:
            df = pd.read_csv(filename,
                             header=None,
                             names=['timestamp', 'jobID', 'job', 'company', 'attempted', 'result'],
                             lineterminator='\n',
                             encoding='utf-8')

            df['timestamp'] = pd.to_datetime(df['timestamp'], format="%Y-%m-%d %H:%M:%S")
            df = df[df['timestamp'] > (datetime.now() - timedelta(days=2))]
            jobIDs = list(df.jobID)
            log.info(f"{len(jobIDs)} jobIDs found")
            return jobIDs
        except Exception as e:
            log.info(str(e) + "   jobIDs could not be loaded from CSV {}".format(filename))
            return None

    def browser_options(self):
        options = Options()
        options.add_argument("--start-maximized")
        options.add_argument("--ignore-certificate-errors")
        options.add_argument('--no-sandbox')
        options.add_argument("--disable-extensions")

        # Disable webdriver flags or you will be easily detectable
        options.add_argument("--disable-blink-features")
        options.add_argument("--disable-blink-features=AutomationControlled")
        return options

    def start_linkedin(self, username, password):
        log.info("Logging in.....Please wait :)  ")
        self.browser.get("https://www.linkedin.com/login?trk=guest_homepage-basic_nav-header-signin")
        try:
            user_field = self.browser.find_element_by_id("username")
            pw_field = self.browser.find_element_by_id("password")
            login_button = self.browser.find_element_by_css_selector(".btn__primary--large")
            user_field.send_keys(username)
            user_field.send_keys(Keys.TAB)
            time.sleep(2)
            pw_field.send_keys(password)
            time.sleep(2)
            login_button.click()
            time.sleep(3)
        except TimeoutException:
            log.info("TimeoutException! Username/password field or login button not found")

    def fill_data(self):
        self.browser.set_window_size(100, 100)
        self.browser.set_window_position(2000, 2000)

    def start_apply(self, positions, locations):
        start = time.time()
        self.fill_data()

        combos = []
        while len(combos) < len(positions) * len(locations):
            position = positions[random.randint(0, len(positions) - 1)]
            location = locations[random.randint(0, len(locations) - 1)]
            combo = (position, location)
            if combo not in combos:
                combos.append(combo)
                log.info(f"Applying to {position}: {location}")
                location = "&location=" + location
                self.applications_loop(position, location)
            if len(combos) > 500:
                break

    # self.finish_apply() --> this does seem to cause more harm than good, since it closes the browser which we usually don't want, other conditions will stop the loop and just break out

    def applications_loop(self, position, location):

        count_application = 0
        count_job = 0
        jobs_per_page = 0
        start_time = time.time()

        log.info("Looking for jobs.. Please wait..")

        self.browser.set_window_position(0, 0)
        self.browser.maximize_window()
        self.browser, _ = self.next_jobs_page(position, location, jobs_per_page)
        log.info("Looking for jobs.. Please wait..")

        while time.time() - start_time < self.MAX_SEARCH_TIME:
            log.info(f"{(self.MAX_SEARCH_TIME - (time.time() - start_time)) // 60} minutes left in this search")

            # sleep to make sure everything loads, add random to make us look human.
            randoTime = random.uniform(3.5, 4.9)
            log.debug(f"Sleeping for {round(randoTime, 1)}")
            time.sleep(randoTime)
            self.load_page(sleep=1)

            # LinkedIn displays the search results in a scrollable <div> on the left side, we have to scroll to its bottom

            scrollresults = self.browser.find_element_by_class_name(
                "jobs-search-results"
            )
            # Selenium only detects visible elements; if we scroll to the bottom too fast, only 8-9 results will be loaded into IDs list
            for i in range(300, 3000, 100):
                self.browser.execute_script("arguments[0].scrollTo(0, {})".format(i), scrollresults)

            time.sleep(4)

            # get job links
            links = self.browser.find_elements_by_xpath(
                '//div[@data-job-id]'
            )

            if len(links) == 0:
                break

            # get job ID of each job link
            IDs = []
            for link in links:
                children = link.find_elements_by_xpath(
                    './/a[@data-control-name]'
                )
                for child in children:
                    if child.text not in self.blacklist:
                        temp = link.get_attribute("data-job-id")
                        jobID = temp.split(":")[-1]
                        IDs.append(int(jobID))
            IDs = set(IDs)

            # remove already applied jobs
            before = len(IDs)
            jobIDs = [x for x in IDs if x not in self.appliedJobIDs]
            after = len(jobIDs)

            # it assumed that 25 jobs are listed in the results window
            if len(jobIDs) == 0 and len(IDs) > 23:
                jobs_per_page = jobs_per_page + 25
                count_job = 0
                self.avoid_lock()
                self.browser, jobs_per_page = self.next_jobs_page(position,
                                                                  location,
                                                                  jobs_per_page)
            # loop over IDs to apply
            for i, jobID in enumerate(jobIDs):
                count_job += 1
                self.get_job_page(jobID)

                # get easy apply button
                button = self.get_easy_apply_button()
                # word filter to skip positions not wanted
                
                if button is not False:
                    if any(word in self.browser.title.split(" ") for word in blackListTitles):
                        log.info('skipping this application, a blacklisted keyword was found in the job position')
                        string_easy = "* Contains blacklisted keyword"
                        result = False
                    elif any(word in self.browser.title.split(" ") for word in keyword_list):
                        string_easy = "* has Easy Apply Button"
                        log.info("Clicking the EASY apply button")
                        button.click()
                        time.sleep(3)
                        result = self.send_resume()
                        count_application += 1
                    else:
                        log.info('Job title does not contain keywords')
                        result = False
                else:
                    log.info("The button does not exist.")
                    string_easy = "* Doesn't have Easy Apply Button"
                    result = False

                position_number = str(count_job + jobs_per_page)
                log.info(f"\nPosition {position_number}:\n {self.browser.title} \n {string_easy} \n")

                self.write_to_file(button, jobID, self.browser.title, result)

                # sleep every 20 applications
                if count_application != 0 and count_application % 20 == 0:
                    sleepTime = random.randint(500, 900)
                    log.info(f"""********count_application: {count_application}************\n\n
                                Time for a nap - see you in:{int(sleepTime / 60)} min
                            ****************************************\n\n""")
                    time.sleep(sleepTime)

                # go to new page if all jobs are done
                if count_job == len(jobIDs):
                    jobs_per_page = jobs_per_page + 25
                    count_job = 0
                    log.info("""****************************************\n\n
                    Going to next jobs page, YEAAAHHH!!
                    ****************************************\n\n""")
                    self.avoid_lock()
                    self.browser, jobs_per_page = self.next_jobs_page(position,
                                                                      location,
                                                                      jobs_per_page)
        # if len(jobIDs) == 0 or i == (len(jobIDs) - 1):
        # break

    def write_to_file(self, button, jobID, browserTitle, result):
        def re_extract(text, pattern):
            target = re.search(pattern, text)
            if target:
                target = target.group(1)
            return target

        timestamp = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
        attempted = False if button == False else True
        job = re_extract(browserTitle.split(' | ')[0], r"\(?\d?\)?\s?(\w.*)")
        company = re_extract(browserTitle.split(' | ')[1], r"(\w.*)")

        toWrite = [timestamp, jobID, job, company, attempted, result]
        with open(self.filename, 'a') as f:
            writer = csv.writer(f)
            writer.writerow(toWrite)

    def get_job_page(self, jobID):

        job = 'https://www.linkedin.com/jobs/view/' + str(jobID)
        self.browser.get(job)
        self.job_page = self.load_page(sleep=0.5)
        return self.job_page

    def get_easy_apply_button(self):
        try:
            button = self.browser.find_elements_by_xpath(
                '//button[contains(@class, "jobs-apply")]/span[1]'
            )

            EasyApplyButton = button[0]
        except:
            EasyApplyButton = False

        return EasyApplyButton

    def send_resume(self):
        def is_present(button_locator):
            return len(self.browser.find_elements(button_locator[0],
                                                  button_locator[1])) > 0

        try:
            time.sleep(random.uniform(1.5, 2.5))
            next_locater = (By.CSS_SELECTOR,
                            "button[aria-label='Continue to next step']")
            review_locater = (By.CSS_SELECTOR,
                              "button[aria-label='Review your application']")
            submit_locater = (By.CSS_SELECTOR,
                              "button[aria-label='Submit application']")
            submit_application_locator = (By.CSS_SELECTOR,
                                          "button[aria-label='Submit application']")
            error_locator = (By.CSS_SELECTOR,
                             "p[data-test-form-element-error-message='true']")
            upload_locator = (By.CSS_SELECTOR, "input[name='file']")

            submitted = False
            while True:

                # Upload Cover Letter if possible
                if is_present(upload_locator):

                    input_buttons = self.browser.find_elements(upload_locator[0],
                                                               upload_locator[1])
                    for input_button in input_buttons:
                        parent = input_button.find_element(By.XPATH, "..")
                        sibling = parent.find_element(By.XPATH, "preceding-sibling::*")
                        grandparent = sibling.find_element(By.XPATH, "..")
                        for key in self.uploads.keys():
                            sibling_text = sibling.text
                            gparent_text = grandparent.text
                            if key.lower() in sibling_text.lower() or key in gparent_text.lower():
                                input_button.send_keys(self.uploads[key])

                    # input_button[0].send_keys(self.cover_letter_loctn)
                    time.sleep(random.uniform(4.5, 6.5))

                # Click Next or submitt button if possible
                button = None
                buttons = [next_locater, review_locater,
                           submit_locater, submit_application_locator]
                for i, button_locator in enumerate(buttons):
                    if is_present(button_locator):
                        button = self.wait.until(EC.element_to_be_clickable(button_locator))

                    if is_present(error_locator):
                        for element in self.browser.find_elements(error_locator[0],
                                                                  error_locator[1]):
                            text = element.text
                            if "Please enter a valid answer" in text:
                                button = None
                                break
                    if button:
                        button.click()
                        time.sleep(random.uniform(1.5, 2.5))
                        if i in (2, 3):
                            submitted = True
                        break
                if button == None:
                    log.info("Could not complete submission")
                    break
                elif submitted:
                    log.info("Application Submitted")
                    break

            time.sleep(random.uniform(1.5, 2.5))


        except Exception as e:
            log.info(e)
            log.info("cannot apply to this job")
            raise (e)

        return submitted

    def load_page(self, sleep=1):
        scroll_page = 0
        while scroll_page < 4000:
            self.browser.execute_script("window.scrollTo(0," + str(scroll_page) + " );")
            scroll_page += 200
            time.sleep(sleep)

        if sleep != 1:
            self.browser.execute_script("window.scrollTo(0,0);")
            time.sleep(sleep * 3)

        page = BeautifulSoup(self.browser.page_source, "lxml")
        return page

    def avoid_lock(self):
        x, _ = pyautogui.position()
        pyautogui.moveTo(x + 200, pyautogui.position().y, duration=1.0)
        pyautogui.moveTo(x, pyautogui.position().y, duration=0.5)
        pyautogui.keyDown('ctrl')
        pyautogui.press('esc')
        pyautogui.keyUp('ctrl')
        time.sleep(0.5)
        pyautogui.press('esc')

    def next_jobs_page(self, position, location, jobs_per_page):
        self.browser.get(
            "https://www.linkedin.com/jobs/search/?distance=100&f_AL=true&f_E=1%2C2&f_TPR=r2592000&f_WT=2%2C1%2C3&keywords=" +
            position + location + "&start=" + str(jobs_per_page))
        self.avoid_lock()
        log.info("Lock avoided.")
        self.load_page()
        return (self.browser, jobs_per_page)

    def finish_apply(self):
        self.browser.close()


if __name__ == '__main__':

    with open("config.yaml", 'r') as stream:
        try:
            parameters = yaml.safe_load(stream)
        except yaml.YAMLError as exc:
            raise exc

    assert len(parameters['positions']) > 0
    assert len(parameters['locations']) > 0
    assert parameters['username'] is not None
    assert parameters['password'] is not None

    if 'uploads' in parameters.keys() and type(parameters['uploads']) == list:
        raise Exception("uploads read from the config file appear to be in list format" +
                        " while should be dict. Try removing '-' from line containing" +
                        " filename & path")

    log.info({k: parameters[k] for k in parameters.keys() if k not in ['username', 'password']})

    output_filename = [f for f in parameters.get('output_filename', ['output.csv']) if f != None]
    output_filename = output_filename[0] if len(output_filename) > 0 else 'output.csv'
    blacklist = parameters.get('blacklist', [])
    blackListTitles = parameters.get('blackListTitles', [])
    keyword_list = parameters.get('keyword_list', [])

    uploads = {} if parameters.get('uploads', {}) == None else parameters.get('uploads', {})
    for key in uploads.keys():
        assert uploads[key] != None

    bot = EasyApplyBot(parameters['username'],
                       parameters['password'],
                       uploads=uploads,
                       filename=output_filename,
                       blacklist=blacklist,
                       blackListTitles=blackListTitles,
                       keyword_list=keyword_list
                       )

    locations = [l for l in parameters['locations'] if l != None]
    positions = [p for p in parameters['positions'] if p != None]
    bot.start_apply(positions, locations)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\trand\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# C:\Users\trand\AppData\Local\Temp\ipykernel_16756\2746898082.py:22: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
# 06:54:19 - INFO - {'positions': ['Python'], 'locations': ['California'], 'uploads': {'Resume': 'C:\\Users\\trand\\OneDrive\\Desktop\\Darren_Tran_Resume.pdf'}, 'blackListTitles': ['AR', 'VR', 'Manager', 'Lead', 'Principal', 'Founding', 'Embedded', 'Java', 'Angular', 'Hadoop', 'MongDB', 'Spark', 'Ruby', 'Rails', 'Frontend', 'Designer', 'Azure', 'GCP', '.Net', '.NET', 'Senior', 'Sr.', 'Embedded', 'PHP', 'iOS', 'Android', 'Swift', 'Salesforce', 'Tableau', 'Mobile', 'Controls', 'API', 'C#', 'C++', 'C', 'Verification', 'Test', 'BI', 'Golang', 'TypeScript', 'Security', 'Network', 'Warehouse', 'Pipeline', 'Prototype', 'Client', 'Growth', 'Hacker', 'Unpaid', 'Report', 'Clearance', 'PhD', 'Minimum', 'Cybersecurity', 'Instructor', 'Teacher', 'Volunteer', 'Student', 'Sales', 'Web'], 'keyword_list': ['Python', 'Engineer', 'Developer', 'Researcher', 'Scientist', 'Programmer']}
# 06:54:19 - INFO - Welcome to Easy Apply Bot
# 06:54:19 - INFO - current directory is : C:\Users\trand\OneDrive\Desktop\Linkedin-Jobs
# 06:54:19 - INFO - 7 jobIDs found
# 06:54:19 - INFO - Logging in.....Please wait :)
# C:\Users\trand\AppData\Local\Temp\ipykernel_16756\2746898082.py:105: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   user_field = self.browser.find_element_by_id("username")
# C:\Users\trand\AppData\Local\Temp\ipykernel_16756\2746898082.py:106: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   pw_field = self.browser.find_element_by_id("password")
# C:\Users\trand\AppData\Local\Temp\ipykernel_16756\2746898082.py:107: DeprecationWarning: find_element_by_css_selector is deprecated. Please use find_element(by=By.CSS_SELECTOR, value=css_selector) instead
#   login_button = self.browser.find_element_by_css_selector(".btn__primary--large")
# 06:54:32 - INFO - Applying to Python: California
# 06:54:32 - INFO - Looking for jobs.. Please wait..
# 06:54:38 - INFO - Lock avoided.
# 06:54:58 - INFO - Looking for jobs.. Please wait..
# 06:54:58 - INFO - 719.0 minutes left in this search
# 06:54:58 - DEBUG - Sleeping for 4.3
# C:\Users\trand\AppData\Local\Temp\ipykernel_16756\2746898082.py:166: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   scrollresults = self.browser.find_element_by_class_name(
# C:\Users\trand\AppData\Local\Temp\ipykernel_16756\2746898082.py:176: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   links = self.browser.find_elements_by_xpath(
# C:\Users\trand\AppData\Local\Temp\ipykernel_16756\2746898082.py:186: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   children = link.find_elements_by_xpath(
# C:\Users\trand\AppData\Local\Temp\ipykernel_16756\2746898082.py:291: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   button = self.browser.find_elements_by_xpath(
# 06:55:44 - INFO - skipping this application, a blacklisted keyword was found in the job position
# 06:55:44 - INFO -
# Position 1:
#  (1) Junior Java Developer | Miracle Software Systems, Inc | LinkedIn
#  * Contains blacklisted keyword
#
# 06:55:58 - INFO - Clicking the EASY apply button
# 06:56:06 - INFO - Application Submitted
# 06:56:08 - INFO -
# Position 2:
#  (1) DevOps Engineer | FastBook Advisors | LinkedIn
#  * has Easy Apply Button
#
# 06:56:22 - INFO - Clicking the EASY apply button
# 06:56:39 - INFO - Application Submitted
# 06:56:41 - INFO -
# Position 3:
#  (1) Data Engineer | BlastPoint | LinkedIn
#  * has Easy Apply Button
#
# 06:56:56 - INFO - The button does not exist.
# 06:56:56 - INFO -
# Position 4:
#  (1) Software Engineer | Blue Marble Communications Inc. | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 06:57:10 - INFO - Job title does not contain keywords
# 06:57:10 - INFO -
# Position 5:
#  Full Stack/Backend Engineers - Multiple positions (Go/Python) | CyberCoders | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 06:57:24 - INFO - Clicking the EASY apply button
# 06:57:32 - INFO - Application Submitted
# 06:57:34 - INFO -
# Position 6:
#  Python Developer | iPartner Staffing | LinkedIn
#  * has Easy Apply Button
#
# 06:57:48 - INFO - Clicking the EASY apply button
# 06:57:55 - INFO - Application Submitted
# 06:57:57 - INFO -
# Position 7:
#  Data Engineer | Mindlance | LinkedIn
#  * has Easy Apply Button
#
# 06:58:11 - INFO - Clicking the EASY apply button
# 06:58:19 - INFO - Application Submitted
# 06:58:21 - INFO -
# Position 8:
#  Informatica Developer | Quantum World Technologies Inc | LinkedIn
#  * has Easy Apply Button
#
# 06:58:34 - INFO - Clicking the EASY apply button
# 06:58:50 - INFO - Application Submitted
# 06:58:52 - INFO -
# Position 9:
#  Python Developer | Mindlance | LinkedIn
#  * has Easy Apply Button
#
# 06:59:06 - INFO - Job title does not contain keywords
# 06:59:06 - INFO -
# Position 10:
#  Full-stack Developer(.NET) | SUNWELLS OXYGEN INDIA PRIVATE LIMITED | LinkedIn
#  * has Easy Apply Button
#
# 06:59:20 - INFO - Clicking the EASY apply button
# 06:59:31 - INFO - Could not complete submission
# 06:59:32 - INFO -
# Position 11:
#  Cloud Engineer | The Scharf Group | LinkedIn
#  * has Easy Apply Button
#
# 06:59:48 - INFO - Clicking the EASY apply button
# 07:00:00 - INFO - Could not complete submission
# 07:00:01 - INFO -
# Position 12:
#  React JS Developer | Proconnxt | LinkedIn
#  * has Easy Apply Button
#
# 07:00:16 - INFO - Clicking the EASY apply button
# 07:00:23 - INFO - Application Submitted
# 07:00:25 - INFO -
# Position 13:
#  Python Developer | SEO and SEM Technologies | LinkedIn
#  * has Easy Apply Button
#
# 07:00:39 - INFO - skipping this application, a blacklisted keyword was found in the job position
# 07:00:39 - INFO -
# Position 14:
#  Senior Software Development Engineer (C/C++/Python) | CyberCoders | LinkedIn
#  * Contains blacklisted keyword
#
# 07:00:53 - INFO - skipping this application, a blacklisted keyword was found in the job position
# 07:00:53 - INFO -
# Position 15:
#  Web Developer | Balanced Nutritionals | LinkedIn
#  * Contains blacklisted keyword
#
# 07:01:07 - INFO - Clicking the EASY apply button
# 07:01:23 - INFO - Application Submitted
# 07:01:26 - INFO -
# Position 16:
#  Autonomy Engineer | EpiSci (EpiSys Science, Inc.) | LinkedIn
#  * has Easy Apply Button
#
# 07:01:40 - INFO - skipping this application, a blacklisted keyword was found in the job position
# 07:01:40 - INFO -
# Position 17:
#  (1) .NET Developer | Enterprise Solutions Inc. | LinkedIn
#  * Contains blacklisted keyword
#
# 07:01:53 - INFO - Clicking the EASY apply button
# 07:02:02 - INFO - Application Submitted
# 07:02:03 - INFO -
# Position 18:
#  (1) Application System Engineer | VSV WINS, INC | LinkedIn
#  * has Easy Apply Button
#
# 07:02:03 - INFO - ****************************************
#
#
#                     Going to next jobs page, YEAAAHHH!!
#                     ****************************************
#
#
# 07:02:13 - INFO - Lock avoided.
# 07:02:33 - INFO - 711.0 minutes left in this search
# 07:02:33 - DEBUG - Sleeping for 3.8
# 07:03:18 - INFO - Clicking the EASY apply button
# 07:03:26 - INFO - Application Submitted
# 07:03:28 - INFO -
# Position 26:
#  (1) Big Data Developer | Altusmeus | LinkedIn
#  * has Easy Apply Button
#
# 07:03:41 - INFO - Clicking the EASY apply button
# 07:03:48 - INFO - Application Submitted
# 07:03:50 - INFO -
# Position 27:
#  (1) System Engineer | Pyramid Consulting, Inc | LinkedIn
#  * has Easy Apply Button
#
# 07:04:05 - INFO - Clicking the EASY apply button
# 07:04:12 - INFO - Application Submitted
# 07:04:14 - INFO -
# Position 28:
#  (1) UI Developer | SEO and SEM Technologies | LinkedIn
#  * has Easy Apply Button
#
# 07:04:27 - INFO - Clicking the EASY apply button
# 07:04:36 - INFO - Application Submitted
# 07:04:38 - INFO -
# Position 29:
#  (1) Software Engineer | Technology Partners | LinkedIn
#  * has Easy Apply Button
#
# 07:04:52 - INFO - Clicking the EASY apply button
# 07:05:05 - INFO - Could not complete submission
# 07:05:07 - INFO -
# Position 30:
#  (1) DevOps Engineer | Revolution Information Technologies Pvt Ltd | LinkedIn
#  * has Easy Apply Button
#
# 07:05:21 - INFO - Clicking the EASY apply button
# 07:05:34 - INFO - Could not complete submission
# 07:05:36 - INFO -
# Position 31:
#  (1) Data Engineer | Systel | LinkedIn
#  * has Easy Apply Button
#
# 07:05:50 - INFO - Clicking the EASY apply button
# 07:06:02 - INFO - Could not complete submission
# 07:06:04 - INFO -
# Position 32:
#  (1) PL/SQL Developer | Bravens Inc. | LinkedIn
#  * has Easy Apply Button
#
# 07:06:18 - INFO - The button does not exist.
# 07:06:18 - INFO -
# Position 33:
#  (1) Python Developer | Pyramid Consulting, Inc | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 07:06:32 - INFO - skipping this application, a blacklisted keyword was found in the job position
# 07:06:32 - INFO -
# Position 34:
#  (1) Java Developer Contract | Precision Technologies | LinkedIn
#  * Contains blacklisted keyword
#
# 07:06:45 - INFO - Clicking the EASY apply button
# 07:06:57 - INFO - Could not complete submission
# 07:07:00 - INFO -
# Position 35:
#  (1) Teamcenter Developer (PLM) | Aquest Staffing | LinkedIn
#  * has Easy Apply Button
#
# 07:07:15 - INFO - Clicking the EASY apply button
# 07:07:23 - INFO - Application Submitted
# 07:07:25 - INFO -
# Position 36:
#  (1) Mulesoft Developer | TechDigital | LinkedIn
#  * has Easy Apply Button
#
# 07:07:25 - INFO - ********count_application: 20************
#
#
#                                 Time for a nap - see you in:10 min
#                             ****************************************
#
#
# 07:18:07 - INFO - The button does not exist.
# 07:18:07 - INFO -
# Position 37:
#  IBM Sterling OMS Developer | Infinity Quest | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 07:18:07 - INFO - ********count_application: 20************
#
#
#                                 Time for a nap - see you in:10 min
#                             ****************************************
#
#
# 07:28:27 - INFO - The button does not exist.
# 07:28:27 - INFO -
# Position 38:
#  .NET Developer | VBeyond Corporation | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 07:28:27 - INFO - ********count_application: 20************
#
#
#                                 Time for a nap - see you in:8 min
#                             ****************************************
#
#
# 07:37:26 - INFO - The button does not exist.
# 07:37:26 - INFO -
# Position 39:
#  Data Engineer, Analyst & Scientist vacancies | OrbiSky Systems | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 07:37:26 - INFO - ********count_application: 20************
#
#
#                                 Time for a nap - see you in:9 min
#                             ****************************************
#
#
# 07:47:27 - INFO - The button does not exist.
# 07:47:27 - INFO -
# Position 40:
#  Java Developer | TechBrains Solutions Inc. | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 07:47:27 - INFO - ********count_application: 20************
#
#
#                                 Time for a nap - see you in:13 min
#                             ****************************************
#
#
# 08:00:55 - INFO - The button does not exist.
# 08:00:55 - INFO -
# Position 41:
#  Software Engineer | Coddy | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 08:00:55 - INFO - ********count_application: 20************
#
#
#                                 Time for a nap - see you in:10 min
#                             ****************************************
#
#
# 08:11:10 - INFO - The button does not exist.
# 08:11:10 - INFO -
# Position 42:
#  Data Analyst | Sky Solutions | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 08:11:10 - INFO - ********count_application: 20************
#
#
#                                 Time for a nap - see you in:14 min
#                             ****************************************
#
#
# 08:25:32 - INFO - The button does not exist.
# 08:25:32 - INFO -
# Position 43:
#  react developer | Nityo Infotech | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 08:25:32 - INFO - ********count_application: 20************
#
#
#                                 Time for a nap - see you in:8 min
#                             ****************************************
#
#
# 08:34:33 - INFO - The button does not exist.
# 08:34:33 - INFO -
# Position 44:
#  Typescript / Front-End Engineer | Sworkit Health | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 08:34:33 - INFO - ********count_application: 20************
#
#
#                                 Time for a nap - see you in:12 min
#                             ****************************************
#
#
# 08:47:19 - INFO - The button does not exist.
# 08:47:19 - INFO -
# Position 45:
#  Python Developer | Veridian Tech Solutions, Inc. | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 08:47:19 - INFO - ********count_application: 20************
#
#
#                                 Time for a nap - see you in:13 min
#                             ****************************************
#
#
# 09:01:28 - INFO - The button does not exist.
# 09:01:28 - INFO -
# Position 46:
#  PL/SQL Developer | Bravens Inc. | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 09:01:28 - INFO - ********count_application: 20************
#
#
#                                 Time for a nap - see you in:9 min
#                             ****************************************
#
#
# 09:11:36 - INFO - The button does not exist.
# 09:11:36 - INFO -
# Position 47:
#  Software Engineer (Python) with Automotive | Apollo Technologies | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 09:11:36 - INFO - ********count_application: 20************
#
#
#                                 Time for a nap - see you in:10 min
#                             ****************************************
#
#
# 09:22:22 - INFO - The button does not exist.
# 09:22:22 - INFO -
# Position 48:
#  Data Engineer | CDRP Technologies | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 09:22:22 - INFO - ********count_application: 20************
#
#
#                                 Time for a nap - see you in:12 min
#                             ****************************************
#
#
# 09:35:21 - INFO - The button does not exist.
# 09:35:21 - INFO -
# Position 49:
#  Angular Developer | Confidential | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 09:35:21 - INFO - ********count_application: 20************
#
#
#                                 Time for a nap - see you in:14 min
#                             ****************************************
#
#
# 09:50:10 - INFO - ****************************************
#
#
#                     Going to next jobs page, YEAAAHHH!!
#                     ****************************************
#
#
# 09:50:19 - INFO - Lock avoided.
# 09:50:39 - INFO - 543.0 minutes left in this search
# 09:50:39 - DEBUG - Sleeping for 3.6
# 09:51:21 - INFO - The button does not exist.
# 09:51:21 - INFO -
# Position 51:
#  Dotnet Developer | V-Soft Consulting Group, Inc. | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 09:51:21 - INFO - ********count_application: 20************
#
#
#                                 Time for a nap - see you in:11 min
#                             ****************************************
#
#
# 10:03:04 - INFO - The button does not exist.
# 10:03:04 - INFO -
# Position 52:
#  Big Data Developer | Altusmeus | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 10:03:04 - INFO - ********count_application: 20************
#
#
#                                 Time for a nap - see you in:14 min
#                             ****************************************
#
#
# 10:17:30 - INFO - The button does not exist.
# 10:17:30 - INFO -
# Position 53:
#  Dynamics Developer | Nityo Infotech | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 10:17:30 - INFO - ********count_application: 20************
#
#
#                                 Time for a nap - see you in:13 min
#                             ****************************************
#
#
# 10:31:37 - INFO - The button does not exist.
# 10:31:37 - INFO -
# Position 54:
#  (1) Decisions Engine Engineer | Global Talent HQ | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 10:31:37 - INFO - ********count_application: 20************
#
#
#                                 Time for a nap - see you in:9 min
#                             ****************************************
# 10:40:52 - INFO - The button does not exist.
# 10:40:52 - INFO -
# Position 55:
#  (1) Dynamics 365 Developer | MERP Systems, Inc. | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 10:40:52 - INFO - ********count_application: 20************
#
#
#                                 Time for a nap - see you in:14 min
#                             ****************************************
#
#
# 10:55:09 - INFO - The button does not exist.
# 10:55:09 - INFO -
# Position 56:
#  (1) Mulesoft Developer | TechDigital | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 10:55:09 - INFO - ********count_application: 20************
#
#
#                                 Time for a nap - see you in:12 min
#                             ****************************************
#
#
# 11:08:17 - INFO - The button does not exist.
# 11:08:17 - INFO -
# Position 57:
#  (1) DevOps Engineer | Revolution Information Technologies Pvt Ltd | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 11:08:17 - INFO - ********count_application: 20************
#
#
#                                 Time for a nap - see you in:9 min
#                             ****************************************
#
#
# 11:17:24 - INFO - ****************************************
#
#
#                     Going to next jobs page, YEAAAHHH!!
#                     ****************************************
#
#
# 11:17:33 - INFO - Lock avoided.
# 11:17:53 - INFO - 456.0 minutes left in this search
# 11:17:53 - DEBUG - Sleeping for 4.6
# 11:18:36 - INFO - The button does not exist.
# 11:18:36 - INFO -
# Position 76:
#  (1) JR Automation Engineer | Insight Global | LinkedIn
#  * Doesn't have Easy Apply Button
#
# 11:18:36 - INFO - ********count_application: 20************
#
#
#                                 Time for a nap - see you in:10 min
#                             ****************************************
